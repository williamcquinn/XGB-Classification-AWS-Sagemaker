# %% [markdown]
# ## Classification leveraging Amazon SageMaker & S3
#
# Performing a classification task on the an employee dataset, training an XGBoost decision tree model to predict a given person's salary (the `WAGP` column) - labeling instances into multiple bins.<br>
#
# - Exploratory Data Analysis on the given dataset
# - Save preprocessed datasets to Amazon S3
# - Use the Amazon Sagemaker platform to train an XGBoost model
# - Evaluate the model on the test set
# - Perform hyperparameter tuning on the XGBoost model

# %% [markdown]
# ### 1. Import packages and Get Amazon IAM execution role & instance region

# %%
import os, sagemaker
from sagemaker import get_execution_role
from sklearn.model_selection import train_test_split

# %%
# Define IAM role- this will be necessary when defining your model
iam_role = get_execution_role()

# Set SageMaker session handle
sess = sagemaker.Session()

# set the region of the instance and get a reference to the client
region = sess.boto_session.region_name

bucket = sess.default_bucket()  # this could also be a hard-coded bucket name

print('Using bucket ' + bucket)
print("Success - the SageMaker instance is in the " + region + " region")
# Out:
# Using bucket sagemaker-us-west-2-932696182434
# Success - the SageMaker instance is in the us-west-2 region

# %% [markdown]
# ### 2. Read data.

# %%
import pandas as pd
import pickle

# Read data from the S3 bucket
file_path = "s3://willquinn-emr01/misc/person_records_merged.csv"

df = pd.read_csv(file_path)
df.head()
# Out:
#    SERIALNO  SPORDER  PUMA  ST   ADJINC  AGEP  CIT  CITWP  COW  DDRS  ...  \
# 0        84        1  2600   1  1007549    19    1    NaN  NaN   2.0  ...
# 1       154        1  2500   1  1007549    55    1    NaN  1.0   2.0  ...
# 2       154        2  2500   1  1007549    56    1    NaN  6.0   2.0  ...
# 3       154        3  2500   1  1007549    21    1    NaN  NaN   2.0  ...
# 4       154        4  2500   1  1007549    21    1    NaN  NaN   1.0  ...
#
#    RACWHT  RC  SFN  SFR    SOCP  VPS  WAOB  FHINS3C  FHINS4C  FHINS5C
# 0       1   0  NaN  NaN     NaN  NaN     1      NaN      NaN      NaN
# 1       0   0  NaN  NaN  411011  NaN     1      NaN      NaN      NaN
# 2       0   0  NaN  NaN  493050  NaN     1      NaN      NaN      NaN
# 3       0   0  NaN  NaN     NaN  NaN     1      NaN      NaN      NaN
# 4       0   0  NaN  NaN     NaN  NaN     1      NaN      NaN      NaN
#
# [5 rows x 127 columns]

# %% [markdown]
# ### Description of Columns
#
# There are lots of columns in the original dataset. However, we'll only use the following columns whose descriptions are given below.
#
#
# AGEP -  Age
#
# COW - Class of worker
#
# WAGP - Wages or salary income past 12 months
#
# JWMNP - Travel time to work
#
# JWTR - Means of transportation to work
#
# MAR - Marital status
#
# PERNP - Total person's earnings
#
# NWAV - Available for work
#
# NWLA - On layoff from work
#
# NWLK - Looking for work
#
# NWAB - Temporary absence from work
#
# SCHL - Educational attainment
#
# WKW - Weeks worked during past 12 months

# %%
colNames = ['AGEP', 'COW', 'WAGP', 'JWMNP', 'JWTR', 'MAR', 'PERNP', 'NWAV', 
            'NWLA', 'NWLK', 'NWAB', 'SCHL', 'WKW']

df = df[colNames]

df.head()
# Out:
#    AGEP  COW     WAGP  JWMNP  JWTR  MAR    PERNP  NWAV  NWLA  NWLK  NWAB  \
# 0    19  NaN      0.0    NaN   NaN    5      0.0   5.0   2.0   2.0   2.0
# 1    55  1.0  52000.0   30.0   1.0    1  52000.0   5.0   3.0   3.0   3.0
# 2    56  6.0      0.0    NaN  11.0    1  99000.0   5.0   3.0   3.0   3.0
# 3    21  NaN      0.0    NaN   NaN    5      0.0   5.0   2.0   2.0   2.0
# 4    21  NaN      0.0    NaN   NaN    5      0.0   5.0   2.0   2.0   2.0
#
#    SCHL  WKW
# 0  19.0  NaN
# 1  20.0  1.0
# 2  16.0  1.0
# 3  19.0  NaN
# 4  19.0  NaN

# %% [markdown]
# ### 3. Filtering data
#
# Find the correlation of the WAGP value with all other features.

# %%
# Find the correlation of each of the features with the target variable WAGP


print('Correlations with WAGP:',
'AGEP:', df['WAGP'].corr(df['AGEP']),
'COW:', df['WAGP'].corr(df['COW']),
'JWMNP:', df['WAGP'].corr(df['JWMNP']),
'JWTR:', df['WAGP'].corr(df['JWTR']),
'MAR:', df['WAGP'].corr(df['MAR']),
'PERNP:', df['WAGP'].corr(df['PERNP']),
'NWAV:', df['WAGP'].corr(df['NWAV']),
'NWLA:', df['WAGP'].corr(df['NWLA']),
'NWLK:', df['WAGP'].corr(df['NWLK']),
'NWAB:', df['WAGP'].corr(df['NWAB']),
'SCHL:', df['WAGP'].corr(df['SCHL']),
'WKW:', df['WAGP'].corr(df['WKW']))
# Out:
# Correlations with WAGP: AGEP: -0.034028422159155004 COW: -0.06277891444051867 JWMNP: 0.10563870072567623 JWTR: -0.026631012265713183 MAR: -0.16781655340177812 PERNP: 0.9507294493107296 NWAV: 0.11007110010819092 NWLA: 0.33443922964541745 NWLK: 0.3253553252937488 NWAB: 0.3238221145931637 SCHL: 0.29196669730890873 WKW: -0.3039528417971109

# %%
# Since PERNP is highly correlated with WAGP, we remove that column from the dataset.


colNames = ['AGEP', 'COW', 'WAGP', 'JWMNP', 'JWTR', 'MAR', 'NWAV', 'NWLA', 'NWLK', 'NWAB', 'SCHL', 'WKW']

df = df[colNames]
df.head()
# Out:
#    AGEP  COW     WAGP  JWMNP  JWTR  MAR  NWAV  NWLA  NWLK  NWAB  SCHL  WKW
# 0    19  NaN      0.0    NaN   NaN    5   5.0   2.0   2.0   2.0  19.0  NaN
# 1    55  1.0  52000.0   30.0   1.0    1   5.0   3.0   3.0   3.0  20.0  1.0
# 2    56  6.0      0.0    NaN  11.0    1   5.0   3.0   3.0   3.0  16.0  1.0
# 3    21  NaN      0.0    NaN   NaN    5   5.0   2.0   2.0   2.0  19.0  NaN
# 4    21  NaN      0.0    NaN   NaN    5   5.0   2.0   2.0   2.0  19.0  NaN

# %%
print("WAGP statistics:")

df.WAGP.describe()
# Out:
# WAGP statistics:
# count    2.582042e+06
# mean     2.565256e+04
# std      4.736001e+04
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      6.000000e+03
# 75%      3.600000e+04
# max      6.600000e+05
# Name: WAGP, dtype: float64

# %% [markdown]
# ### 4. Outlier Removal
#
# Remove outlier rows based on values in the `WAGP` column.

# %%
# Selecting the number of standard deviations to set as the upper limit
nStddevs = 3
    
# Finding the mean and standard deviations of the WAGP column
nSamples = len(df)
colName = 'WAGP'

mu = df.WAGP.mean()
sigma = df.WAGP.std()
print('\n{} -- mean:\t{}\n\tstddev:\t{}'.format(colName, mu, sigma))

# Calculating the value of the WAGP upper limit using the calculated mean and standard deviation
upperLim = mu + nStddevs*sigma
print('Removing rows with {} above {}'.format(colName, upperLim))

# Selecting rows using the WAGP upper limit that have been calculated
df_filtered = df[df[colName] < upperLim]
print (nSamples - len(df_filtered), 'rows removed\n')

df_filtered.head(5)
# Out:
# WAGP -- mean:	25652.55809239354
# 	stddev:	47360.01051275194
# Removing rows with WAGP above 167732.58963064937
# 588315 rows removed
#    AGEP  COW     WAGP  JWMNP  JWTR  MAR  NWAV  NWLA  NWLK  NWAB  SCHL  WKW
# 0    19  NaN      0.0    NaN   NaN    5   5.0   2.0   2.0   2.0  19.0  NaN
# 1    55  1.0  52000.0   30.0   1.0    1   5.0   3.0   3.0   3.0  20.0  1.0
# 2    56  6.0      0.0    NaN  11.0    1   5.0   3.0   3.0   3.0  16.0  1.0
# 3    21  NaN      0.0    NaN   NaN    5   5.0   2.0   2.0   2.0  19.0  NaN
# 4    21  NaN      0.0    NaN   NaN    5   5.0   2.0   2.0   2.0  19.0  NaN

# %% [markdown]
# ### 5. Dropping NAs
#
# Drop rows with any nulls in any of the columns.

# %%
"""Remove all rows which have any of the variables as NaN."""

labelCol = 'WAGP'

""""These are the features that we'll use - this does not include WAGP."""
featureCols = ['AGEP', 'COW', 'JWMNP', 'JWTR', 'MAR', 'NWAV', 'NWLA', 'NWLK', 'NWAB', 'SCHL', 'WKW'] 

df_cleaned = df_filtered[[labelCol] + featureCols].dropna(how='any')
print("Num rows left: ", len(df_cleaned))
# Out:
# Num rows left:  1282781

# %% [markdown]
# ### 6. Discretize salary
#
# Convert the WAGP column, into a column with discrete labels so that we can use it as the label column for our classification problem.

# %%
# Categorizing the labels into multiple bins - 5 bins in this case

import matplotlib.pyplot as plt

df_cleaned['WAGP_CAT'] = pd.cut(df_cleaned['WAGP'], bins=5, labels=[0,1,2,3,4])

# Plot a histogram of the WAGP_CAT column
df_cleaned.reset_index(drop = True)
df_cleaned['WAGP_CAT'] = df_cleaned['WAGP_CAT'].astype(int)
ax = df_cleaned.hist(column = 'WAGP_CAT', bins = 5)
#plt.show()


df_cleaned.head(5)
# Out:
#        WAGP  AGEP  COW  JWMNP  JWTR  MAR  NWAV  NWLA  NWLK  NWAB  SCHL  WKW  \
# 1   52000.0    55  1.0   30.0   1.0    1   5.0   3.0   3.0   3.0  20.0  1.0
# 5   39000.0    63  3.0   15.0   1.0    3   5.0   3.0   3.0   3.0  21.0  1.0
# 11  90000.0    59  1.0   10.0   1.0    1   1.0   2.0   2.0   2.0  16.0  1.0
# 12  46000.0    56  1.0   45.0   1.0    1   5.0   3.0   3.0   3.0  18.0  1.0
# 16  20000.0    72  4.0    5.0   1.0    1   5.0   3.0   3.0   3.0  21.0  1.0
#
#     WAGP_CAT
# 1          1
# 5          1
# 11         2
# 12         1
# 16         0

# %%
cols = df_cleaned.columns.tolist()
df_cleaned2 = df_cleaned[cols[-1:] + cols[:-1]].drop('WAGP', axis=1)
df_cleaned2.head()
# Out:
#     WAGP_CAT  AGEP  COW  JWMNP  JWTR  MAR  NWAV  NWLA  NWLK  NWAB  SCHL  WKW
# 1          1    55  1.0   30.0   1.0    1   5.0   3.0   3.0   3.0  20.0  1.0
# 5          1    63  3.0   15.0   1.0    3   5.0   3.0   3.0   3.0  21.0  1.0
# 11         2    59  1.0   10.0   1.0    1   1.0   2.0   2.0   2.0  16.0  1.0
# 12         1    56  1.0   45.0   1.0    1   5.0   3.0   3.0   3.0  18.0  1.0
# 16         0    72  4.0    5.0   1.0    1   5.0   3.0   3.0   3.0  21.0  1.0

# %% [markdown]
# ### 7. Splitting data and converting to CSV

# %%
# Split train_data and val_data with an 80:20 ratio, and then
# Split the train_data into train_data and test_data in a 90:10 ratio.

# Parameters for train_test_split:
# random_state = 42
# shuffle = True

# train_size = 0.8, test_size = 0.2 for the first split
# train_size = 0.9, test_size = 0.1 for the second split

train_data, val_data = train_test_split(df_cleaned2, test_size = 0.2, random_state = 42, shuffle = True)

train_data, test_data = train_test_split(df_cleaned2, test_size = 0.1, random_state = 42, shuffle = True)

len(train_data), len(val_data), len(test_data)
# Out:
# (1154502, 256557, 128279)

# %%
train_data.to_csv('train_data.csv', index=False, header=False)
val_data.to_csv('val_data.csv', index=False, header=False)
test_data.to_csv('test_data.csv', index=False, header=False)

# %% [markdown]
# ### 8. Save processed data to S3

# %%
# Sending data to S3

prefix = "classification-person"
key_prefix = prefix + "/model_data"

trainpath = sess.upload_data(
    path='train_data.csv', bucket=bucket,
    key_prefix=key_prefix)

valpath = sess.upload_data(
    path='val_data.csv', bucket=bucket,
    key_prefix=key_prefix)

testpath = sess.upload_data(
    path='test_data.csv', bucket=bucket,
    key_prefix=key_prefix)

# %%
trainpath, valpath, testpath
# Out:
# ('s3://sagemaker-us-west-2-932696182434/classification-person/model_data/train_data.csv',
#  's3://sagemaker-us-west-2-932696182434/classification-person/model_data/val_data.csv',
#  's3://sagemaker-us-west-2-932696182434/classification-person/model_data/test_data.csv')

# %% [markdown]
# ## 9. Create channels for train and validation data to feed to model

# %%
# Setting up data channels for the training, validation, and test data.
# Using the TrainingInput function and pass the s3_data and content_type parameters

s3_input_train = sagemaker.inputs.TrainingInput(s3_data=trainpath, content_type='csv')
s3_input_val = sagemaker.inputs.TrainingInput(s3_data=valpath, content_type='csv')
s3_input_test = sagemaker.inputs.TrainingInput(s3_data=testpath, content_type='csv')

# %%
# Setting model output location

output_location = "s3://{}/{}/model".format(bucket,prefix)
print('Training artifacts will be uploaded to: {}'.format(output_location))
# Out:
# Training artifacts will be uploaded to: s3://sagemaker-us-west-2-932696182434/classification-person/model

# %% [markdown]
# ### 10. Building the XGBoost model

# %%
# Building the XGBoost model, and setting hyperparameters.

from sagemaker.amazon.amazon_estimator import image_uris
xgb_image = image_uris.retrieve(framework="xgboost", region=region, version='latest')

# %%
# Creating an Estimator using sagemaker.estimator.Estimator.
# Passing the xgb_image and the iam_role parameters.

# Using the following values for other parameters:

# instance_count = 1
# instance_type = ml.m5.xlarge
# output_path = output_location
# sagemaker_session = sess 


xgb = sagemaker.estimator.Estimator(xgb_image,
                                          iam_role, 
                                          instance_count=1, 
                                          instance_type='ml.m5.xlarge',
                                          # train_volume_size = 5,
                                          output_path=output_location,
                                          sagemaker_session=sess)

# %% [markdown]
# ### 11. Set model hyperparameters

# %%
# Using the following values for the parameters:

# num_class = 5,
# max_depth = 2,
# min_child_weight = 2,
# early_stopping_rounds=5,
# objective='multi:softmax',
# num_round=100


xgb.set_hyperparameters(max_depth = 2,             
                        objective = "multi:softmax",
                        num_class = 5,
                        min_child_weight = 2,
                        early_stopping_rounds=5,
                        num_round = 100)

# %% [markdown]
# ### 12. Training the model using train and validation data channels

# %%
# %%time

xgb.fit({'train': s3_input_train, 'validation': s3_input_val})
# Out:
# 2021-03-13 22:41:37 Starting - Starting the training job...
# 2021-03-13 22:42:00 Starting - Launching requested ML instancesProfilerReport-1615675297: InProgress
# ......
# 2021-03-13 22:43:06 Starting - Preparing the instances for training......
# 2021-03-13 22:44:01 Downloading - Downloading input data
# 2021-03-13 22:44:01 Training - Downloading the training image..Arguments: train
# [2021-03-13:22:44:10:INFO] Running standalone xgboost training.
# [2021-03-13:22:44:10:INFO] File size need to be processed in the node: 60.42mb. Available memory size in the node: 7890.27mb
# [2021-03-13:22:44:10:INFO] Determined delimiter of CSV input is ','
# [22:44:10] S3DistributionType set as FullyReplicated
# [22:44:11] 1154502x11 matrix with 12699522 entries loaded from /opt/ml/input/data/train?format=csv&label_column=0&delimiter=,
# [2021-03-13:22:44:11:INFO] Determined delimiter of CSV input is ','
# [22:44:11] S3DistributionType set as FullyReplicated
# [22:44:11] 256557x11 matrix with 2822127 entries loaded from /opt/ml/input/data/validation?format=csv&label_column=0&delimiter=,
# [22:44:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [0]#011train-merror:0.434458#011validation-merror:0.434021
# Multiple eval metrics have been passed: 'validation-merror' will be used for early stopping.
#
# Will train until validation-merror hasn't improved in 5 rounds.
# [22:44:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [1]#011train-merror:0.42711#011validation-merror:0.427118
# [22:44:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [2]#011train-merror:0.436413#011validation-merror:0.436231
# [22:44:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [3]#011train-merror:0.42708#011validation-merror:0.427075
# [22:44:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [4]#011train-merror:0.426917#011validation-merror:0.426856
# [22:44:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [5]#011train-merror:0.418561#011validation-merror:0.418129
# [22:44:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [6]#011train-merror:0.418747#011validation-merror:0.418242
# [22:44:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [7]#011train-merror:0.419432#011validation-merror:0.419119
# [22:44:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [8]#011train-merror:0.418672#011validation-merror:0.418055
# [22:44:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [9]#011train-merror:0.418429#011validation-merror:0.417747
# [22:44:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [10]#011train-merror:0.418084#011validation-merror:0.417724
# [22:44:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [11]#011train-merror:0.416986#011validation-merror:0.416547
# [22:44:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [12]#011train-merror:0.41673#011validation-merror:0.416278
# [22:44:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [13]#011train-merror:0.41214#011validation-merror:0.412006
# [22:44:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [14]#011train-merror:0.411181#011validation-merror:0.41079
# [22:44:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [15]#011train-merror:0.411052#011validation-merror:0.410778
# [22:44:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [16]#011train-merror:0.410201#011validation-merror:0.409737
# [22:44:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
#
# 2021-03-13 22:44:21 Training - Training image download completed. Training in progress.[22:44:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17]#011train-merror:0.409685#011validation-merror:0.409426
# [22:44:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [18]#011train-merror:0.407461#011validation-merror:0.407286
# [22:44:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [19]#011train-merror:0.406056#011validation-merror:0.405606
# [22:44:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [20]#011train-merror:0.404985#011validation-merror:0.404331
# [22:44:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [21]#011train-merror:0.402735#011validation-merror:0.40225
# [22:44:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22]#011train-merror:0.402315#011validation-merror:0.401911
# [22:44:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [23]#011train-merror:0.402118#011validation-merror:0.401802
# [22:44:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [24]#011train-merror:0.401914#011validation-merror:0.401455
# [22:44:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [25]#011train-merror:0.40159#011validation-merror:0.401108
# [22:44:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [26]#011train-merror:0.401531#011validation-merror:0.401034
# [22:44:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [27]#011train-merror:0.401097#011validation-merror:0.400609
# [22:44:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [28]#011train-merror:0.400834#011validation-merror:0.400328
# [22:44:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [29]#011train-merror:0.400502#011validation-merror:0.400055
# [22:44:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [30]#011train-merror:0.40038#011validation-merror:0.399915
# [22:44:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [31]#011train-merror:0.400182#011validation-merror:0.399771
# [22:44:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [32]#011train-merror:0.399446#011validation-merror:0.398913
# [22:44:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [33]#011train-merror:0.39939#011validation-merror:0.39887
# [22:44:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [34]#011train-merror:0.398933#011validation-merror:0.398375
# [22:44:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [35]#011train-merror:0.398906#011validation-merror:0.398251
# [22:44:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [36]#011train-merror:0.398608#011validation-merror:0.398138
# [22:44:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [37]#011train-merror:0.39827#011validation-merror:0.397931
# [22:44:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [38]#011train-merror:0.397957#011validation-merror:0.397654
# [22:44:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [39]#011train-merror:0.397814#011validation-merror:0.397385
# [22:44:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [40]#011train-merror:0.397587#011validation-merror:0.397417
# [22:44:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [41]#011train-merror:0.397425#011validation-merror:0.396902
# [22:44:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [42]#011train-merror:0.397353#011validation-merror:0.396766
# [22:44:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [43]#011train-merror:0.397159#011validation-merror:0.396501
# [22:44:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [44]#011train-merror:0.397162#011validation-merror:0.396489
# [22:44:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [45]#011train-merror:0.396903#011validation-merror:0.396189
# [22:44:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [46]#011train-merror:0.396894#011validation-merror:0.396107
# [22:44:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [47]#011train-merror:0.396508#011validation-merror:0.395974
# [22:44:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [48]#011train-merror:0.396193#011validation-merror:0.395666
# [22:44:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [49]#011train-merror:0.396083#011validation-merror:0.395386
# [22:44:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [50]#011train-merror:0.395953#011validation-merror:0.39509
# [22:44:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [51]#011train-merror:0.395702#011validation-merror:0.395023
# [22:44:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [52]#011train-merror:0.395649#011validation-merror:0.394832
# [22:44:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [53]#011train-merror:0.395518#011validation-merror:0.394544
# [22:44:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [54]#011train-merror:0.395447#011validation-merror:0.394536
# [22:44:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [55]#011train-merror:0.395325#011validation-merror:0.394353
# [22:44:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:44:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [56]#011train-merror:0.395222#011validation-merror:0.394275
# [22:45:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [57]#011train-merror:0.394983#011validation-merror:0.393959
# [22:45:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [58]#011train-merror:0.394939#011validation-merror:0.393936
# [22:45:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [59]#011train-merror:0.394633#011validation-merror:0.393628
# [22:45:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [60]#011train-merror:0.393785#011validation-merror:0.392981
# [22:45:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [61]#011train-merror:0.393777#011validation-merror:0.392977
# [22:45:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [62]#011train-merror:0.39361#011validation-merror:0.392864
# [22:45:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [63]#011train-merror:0.393352#011validation-merror:0.392798
# [22:45:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [64]#011train-merror:0.393407#011validation-merror:0.392576
# [22:45:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [65]#011train-merror:0.393157#011validation-merror:0.392322
# [22:45:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [66]#011train-merror:0.393143#011validation-merror:0.392486
# [22:45:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [67]#011train-merror:0.393048#011validation-merror:0.392416
# [22:45:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [68]#011train-merror:0.392958#011validation-merror:0.392338
# [22:45:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [69]#011train-merror:0.392775#011validation-merror:0.392357
# [22:45:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [70]#011train-merror:0.392647#011validation-merror:0.392186
# [22:45:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [71]#011train-merror:0.392412#011validation-merror:0.391983
# [22:45:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [72]#011train-merror:0.392393#011validation-merror:0.39196
# [22:45:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [73]#011train-merror:0.392313#011validation-merror:0.391971
# [22:45:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [74]#011train-merror:0.391983#011validation-merror:0.391511
# [22:45:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [75]#011train-merror:0.391765#011validation-merror:0.391398
# [22:45:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [76]#011train-merror:0.391732#011validation-merror:0.391422
# [22:45:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [77]#011train-merror:0.391655#011validation-merror:0.391371
# [22:45:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [78]#011train-merror:0.391615#011validation-merror:0.391313
# [22:45:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [79]#011train-merror:0.391545#011validation-merror:0.391258
# [22:45:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [80]#011train-merror:0.391493#011validation-merror:0.391071
# [22:45:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [81]#011train-merror:0.391444#011validation-merror:0.39097
# [22:45:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [82]#011train-merror:0.391215#011validation-merror:0.390818
# [22:45:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [83]#011train-merror:0.391172#011validation-merror:0.39079
# [22:45:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [84]#011train-merror:0.391124#011validation-merror:0.390744
# [22:45:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [85]#011train-merror:0.391135#011validation-merror:0.390783
# [22:45:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [86]#011train-merror:0.391116#011validation-merror:0.390763
# [22:45:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [87]#011train-merror:0.39096#011validation-merror:0.390518
# [22:45:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
#
# 2021-03-13 22:45:38 Uploading - Uploading generated training model[22:45:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [88]#011train-merror:0.390981#011validation-merror:0.390564
# [22:45:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [89]#011train-merror:0.390872#011validation-merror:0.390447
# [22:45:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [90]#011train-merror:0.390867#011validation-merror:0.390393
# [22:45:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [91]#011train-merror:0.390815#011validation-merror:0.390377
# [22:45:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [92]#011train-merror:0.390744#011validation-merror:0.390381
# [22:45:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [93]#011train-merror:0.390603#011validation-merror:0.390151
# [22:45:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [94]#011train-merror:0.390468#011validation-merror:0.390093
# [22:45:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [95]#011train-merror:0.39036#011validation-merror:0.389945
# [22:45:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [96]#011train-merror:0.390403#011validation-merror:0.390022
# [22:45:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [97]#011train-merror:0.390446#011validation-merror:0.389921
# [22:45:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [98]#011train-merror:0.39037#011validation-merror:0.389921
# [22:45:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [22:45:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [99]#011train-merror:0.390325#011validation-merror:0.389796
#
# 2021-03-13 22:46:01 Completed - Training job completed
# ProfilerReport-1615675297: NoIssuesFound
# Training seconds: 124
# Billable seconds: 124
# CPU times: user 573 ms, sys: 45.7 ms, total: 619 ms
# Wall time: 4min 44s

# %% [markdown]
# ### 13. Deploying model

# %%
# %%time

# Deploying model so that it can be used for inference.

# Parameters:

# initial_instance_count = 1,
# instance_type = 'ml.t2.medium',
# serializer = sagemaker.serializers.CSVSerializer(),


xgb_predictor = xgb.deploy(initial_instance_count=1,
                                 serializer = sagemaker.serializers.CSVSerializer(),
                                 instance_type='ml.t2.medium')
# Out:
# -------------!CPU times: user 192 ms, sys: 15.9 ms, total: 207 ms
# Wall time: 6min 32s

# %% [markdown]
# ### 14. Testing the model on test data

# %%
import numpy as np

test_data_array = test_data.drop(['WAGP_CAT'], axis=1).values #load the data into an array
test_data.head(1)

predictions = xgb_predictor.predict(data=test_data_array).decode('utf-8') # predict!
predictions_array = np.fromstring(predictions[1:-1], sep=',') # and turn the prediction into an array
print(predictions_array.shape)

y_true = np.array(test_data['WAGP_CAT'].values)
y_pred = predictions_array
# Out:
# (128279,)

# %% [markdown]
# ### 15. Confusion matrix and classification report

# %%
from sklearn.metrics import confusion_matrix, classification_report

print(confusion_matrix(y_true, y_pred))
print(classification_report(y_true, y_pred))
# Out:
# [[54392 11800   552     5     0]
#  [15955 21962  1239     7     1]
#  [ 3321 10206  1910     9     3]
#  [  622  2800  1246     9     1]
#  [  315  1134   777    13     0]]
#               precision    recall  f1-score   support
#
#            0       0.73      0.81      0.77     66749
#            1       0.46      0.56      0.50     39164
#            2       0.33      0.12      0.18     15449
#            3       0.21      0.00      0.00      4678
#            4       0.00      0.00      0.00      2239
#
#     accuracy                           0.61    128279
#    macro avg       0.35      0.30      0.29    128279
# weighted avg       0.57      0.61      0.58    128279

# %% [markdown]
# #### Delete Endpoint

# %%
xgb_predictor.delete_endpoint()

# %% [markdown]
# ### 16. Hyperparameter tuning

# %%
#Hyperparameter tuning on two hyperparameters: min_child_weight, max_depth

from sagemaker.tuner import IntegerParameter


# Define exploration boundaries
hyperparameter_ranges = {'max_depth': IntegerParameter(1, 10),
    'min_child_weight': IntegerParameter(1,10)}

# create Optimizer
Optimizer = sagemaker.tuner.HyperparameterTuner(
    estimator=xgb,
    hyperparameter_ranges=hyperparameter_ranges,
    base_tuning_job_name='XGBoost-Tuner',
    objective_type='Minimize',
    objective_metric_name='validation:merror',
    max_jobs=5,
    max_parallel_jobs=5,
    strategy='Random')

# %%
# %%time

Optimizer.fit({'train': s3_input_train, 'validation': s3_input_val})
# Out:
# .................................................................................................!
# CPU times: user 435 ms, sys: 17.9 ms, total: 453 ms
# Wall time: 8min 10s

# %% [markdown]
# ### 17. Results of tuning job

# %%
results = Optimizer.analytics().dataframe()
results
# Out:
#    max_depth  min_child_weight                         TrainingJobName  \
# 0        2.0               5.0  XGBoost-Tuner-210313-2257-005-884a7bd8
# 1        1.0               8.0  XGBoost-Tuner-210313-2257-004-d208a723
# 2        2.0               3.0  XGBoost-Tuner-210313-2257-003-b7b0831d
# 3        7.0               1.0  XGBoost-Tuner-210313-2257-002-58b4100d
# 4        5.0               7.0  XGBoost-Tuner-210313-2257-001-cb509ea7
#
#   TrainingJobStatus  FinalObjectiveValue         TrainingStartTime  \
# 0         Completed             0.390132 2021-03-13 22:59:15+00:00
# 1         Completed             0.478054 2021-03-13 22:59:28+00:00
# 2         Completed             0.390019 2021-03-13 22:59:38+00:00
# 3         Completed             0.384421 2021-03-13 22:59:15+00:00
# 4         Completed             0.386709 2021-03-13 22:59:30+00:00
#
#             TrainingEndTime  TrainingElapsedTimeSeconds
# 0 2021-03-13 23:01:36+00:00                       141.0
# 1 2021-03-13 23:00:45+00:00                        77.0
# 2 2021-03-13 23:01:50+00:00                       132.0
# 3 2021-03-13 23:05:03+00:00                       348.0
# 4 2021-03-13 23:02:19+00:00                       169.0

# %%
Optimizer.best_estimator().hyperparameters()
# Out:
# 2021-03-13 23:05:03 Starting - Preparing the instances for training
# 2021-03-13 23:05:03 Downloading - Downloading input data
# 2021-03-13 23:05:03 Training - Training image download completed. Training in progress.
# 2021-03-13 23:05:03 Uploading - Uploading generated training model
# 2021-03-13 23:05:03 Completed - Training job completed
# {'_tuning_objective_metric': 'validation:merror',
#  'early_stopping_rounds': '5',
#  'max_depth': '7',
#  'min_child_weight': '1',
#  'num_class': '5',
#  'num_round': '100',
#  'objective': 'multi:softmax'}

# %% [markdown]
# ### 18. Deploy the tuned model.

# %%
tuned_model_predictor = Optimizer.deploy(initial_instance_count=1,
                    instance_type='ml.m5.xlarge', serializer = sagemaker.serializers.CSVSerializer())
# Out:
# 2021-03-13 23:05:03 Starting - Preparing the instances for training
# 2021-03-13 23:05:03 Downloading - Downloading input data
# 2021-03-13 23:05:03 Training - Training image download completed. Training in progress.
# 2021-03-13 23:05:03 Uploading - Uploading generated training model
# 2021-03-13 23:05:03 Completed - Training job completed
# -------------!

# %% [markdown]
# ### 19. Test the tuned model on test data

# %%
predictions_tuned = tuned_model_predictor.predict(data=test_data_array).decode('utf-8') # predict!
predictions_array_tuned = np.fromstring(predictions_tuned[1:-1], sep=',') # and turn the prediction into an array
print(predictions_array_tuned.shape)

y_true = np.array(test_data['WAGP_CAT'].values)
y_pred = predictions_array_tuned

# Print the confusion matrix to compare with the initial model.
print(confusion_matrix(y_true, y_pred))
print(classification_report(y_true, y_pred))
# Out:
# (128279,)
# [[53549 12427   759     8     6]
#  [14889 22157  2083    29     6]
#  [ 3110  9446  2813    62    18]
#  [  574  2412  1616    55    21]
#  [  284   985   901    44    25]]
#               precision    recall  f1-score   support
#
#            0       0.74      0.80      0.77     66749
#            1       0.47      0.57      0.51     39164
#            2       0.34      0.18      0.24     15449
#            3       0.28      0.01      0.02      4678
#            4       0.33      0.01      0.02      2239
#
#     accuracy                           0.61    128279
#    macro avg       0.43      0.31      0.31    128279
# weighted avg       0.58      0.61      0.59    128279
# "You should see that the tuned model gives you better performance in the f1-score for each (or most) of \nthe classses.\nIf not, then you're probably doing something wrong."

# %% [markdown]
# ### Delete Endpoint

# %%
tuned_model_predictor.delete_endpoint()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-28d177e6b708> in <module>
# ----> 1 tuned_model_predictor.delete_endpoint()
#
# NameError: name 'tuned_model_predictor' is not defined
